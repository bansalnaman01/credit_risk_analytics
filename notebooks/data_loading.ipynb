# %%
# !pip install pandas numpy scikit-learn
# Out:
# Requirement already satisfied: pandas in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: scikit-learn in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/naman-bansal/credit_risk_analytics/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report

# %%
df = pd.read_csv("../data/german_credit_data.csv")

# Basic checks
print(df.shape)
print(df.columns)
df.head()
# Out:
# (1000, 10)
# Index(['Unnamed: 0', 'Age', 'Sex', 'Job', 'Housing', 'Saving accounts',
#        'Checking account', 'Credit amount', 'Duration', 'Purpose'],
#       dtype='object')
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
# Check missing values
df.isnull().sum()

# Fill missing categorical values with mode
df["Saving accounts"].fillna(df["Saving accounts"].mode()[0], inplace=True)
df["Checking account"].fillna(df["Checking account"].median(), inplace=True)
# Out:
# /tmp/ipykernel_30204/25824848.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Saving accounts"].fillna(df["Saving accounts"].mode()[0], inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 # Fill missing categorical values with mode
#       5 df["Saving accounts"].fillna(df["Saving accounts"].mode()[0], inplace=True)
# ----> 6 df["Checking account"].fillna(df["Checking account"].median(), inplace=True)
#
# File ~/credit_risk_analytics/.venv/lib/python3.13/site-packages/pandas/core/series.py:6580, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6572 @doc(make_doc("median", ndim=1))
#    6573 def median(
#    6574     self,
#    (...)   6578     **kwargs,
#    6579 ):
# -> 6580     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/credit_risk_analytics/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12496, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12489 def median(
#   12490     self,
#   12491     axis: Axis | None = 0,
#    (...)  12494     **kwargs,
#   12495 ) -> Series | float:
# > 12496     return self._stat_function(
#   12497         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12498     )
#
# File ~/credit_risk_analytics/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~/credit_risk_analytics/.venv/lib/python3.13/site-packages/pandas/core/series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~/credit_risk_analytics/.venv/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File 